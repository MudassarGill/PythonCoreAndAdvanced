# %%
#try except


try:
    for i in range(1,10):
        if i/0:
            print('Value : {i}')
except:
    print('Zero not devided by any number')
# Out:
# Zero not devided by any number

# %%
try:
 numbers=[2,34,5,67,7]
 for i in numbers:
    if i*0==10:
     print('Zero multiple is number !!!!')
except ZeroDivisionError: 
    print('ZeroDicision Error')
except TypeError:
    print('Value not found')

# %%
try:
    num = int(input("Enter number: "))
    print(10 / num)

except ZeroDivisionError:
    print("Number cannot be zero")

except ValueError:
    print("Invalid input")
# Out:
# 3.3333333333333335

# %%
try:
    file = open("data.txt")
    content = file.read()
    print(content)

except FileNotFoundError:
    print("File not found")
# Out:
# File not found
